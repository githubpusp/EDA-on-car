# %%
# 1.Filter rows based on a condition , age should be greater than 25
# 2. Sort the DataFrame by age column in descending order
# 3. check for missing value
# 4. check for dulicates 
# data = {'Name': ['John', 'Jane', 'Alex'], 'Age': [25, 30, 28], 'City': ['New York', 'London', 'Paris']}

import pandas as pd

data = {'Name': ['John', 'Jane', 'Alex'],
        'Age': [25, 30, 28],
        'City': ['New York', 'London', 'Paris']}

df = pd.DataFrame(data)  

filtered_df = df[df['Age'] > 25]  

print(filtered_df)
# Out:
#    Name  Age    City
# 1  Jane   30  London
# 2  Alex   28   Paris

# %%
sorted_df = df.sort_values(by='Age', ascending=False)  

print(sorted_df)
# Out:
#    Name  Age      City
# 1  Jane   30    London
# 2  Alex   28     Paris
# 0  John   25  New York

# %%
missing_values = df.isnull().sum()  

print(missing_values)
# Out:
# Name    0
# Age     0
# City    0
# dtype: int64

# %%
duplicate_rows = df.duplicated()  

print(duplicate_rows)
# Out:
# 0    False
# 1    False
# 2    False
# dtype: bool

# %%
# 9-6-23
import pandas as pd

data=pd.read_csv('car_price_prediction.csv')

# %%
dataf=pd.DataFrame(data)
print(dataf)
# Out:
#              ID  Price  Levy   Manufacturer    Model  Prod. year   Category  \
# 0      45654403  13328  1399          LEXUS   RX 450        2010       Jeep
# 1      44731507  16621  1018      CHEVROLET  Equinox        2011       Jeep
# 2      45774419   8467     -          HONDA      FIT        2006  Hatchback
# 3      45769185   3607   862           FORD   Escape        2011       Jeep
# 4      45809263  11726   446          HONDA      FIT        2014  Hatchback
# ...         ...    ...   ...            ...      ...         ...        ...
# 19232  45798355   8467     -  MERCEDES-BENZ  CLK 200        1999      Coupe
# 19233  45778856  15681   831        HYUNDAI   Sonata        2011      Sedan
# 19234  45804997  26108   836        HYUNDAI   Tucson        2010       Jeep
# 19235  45793526   5331  1288      CHEVROLET  Captiva        2007       Jeep
# 19236  45813273    470   753        HYUNDAI   Sonata        2012      Sedan
#
#       Leather interior Fuel type Engine volume    Mileage  Cylinders  \
# 0                  Yes    Hybrid           3.5  186005 km          6
# 1                   No    Petrol             3  192000 km          6
# 2                   No    Petrol           1.3  200000 km          4
# 3                  Yes    Hybrid           2.5  168966 km          4
# 4                  Yes    Petrol           1.3   91901 km          4
# ...                ...       ...           ...        ...        ...
# 19232              Yes       CNG     2.0 Turbo  300000 km          4
# 19233              Yes    Petrol           2.4  161600 km          4
# 19234              Yes    Diesel             2  116365 km          4
# 19235              Yes    Diesel             2   51258 km          4
# 19236              Yes    Hybrid           2.4  186923 km          4
#
#       Gear box type Drive wheels  Doors             Wheel   Color  Airbags
# 0         Automatic          4x4  4-May        Left wheel  Silver       12
# 1         Tiptronic          4x4  4-May        Left wheel   Black        8
# 2          Variator        Front  4-May  Right-hand drive   Black        2
# 3         Automatic          4x4  4-May        Left wheel   White        0
# 4         Automatic        Front  4-May        Left wheel  Silver        4
# ...             ...          ...    ...               ...     ...      ...
# 19232        Manual         Rear  2-Mar        Left wheel  Silver        5
# 19233     Tiptronic        Front  4-May        Left wheel     Red        8
# 19234     Automatic        Front  4-May        Left wheel    Grey        4
# 19235     Automatic        Front  4-May        Left wheel   Black        4
# 19236     Automatic        Front  4-May        Left wheel   White       12
#
# [19237 rows x 18 columns]

# %%
print(dataf)
# Out:
#              ID  Price  Levy   Manufacturer    Model  Prod. year   Category  \
# 0      45654403  13328  1399          LEXUS   RX 450        2010       Jeep
# 1      44731507  16621  1018      CHEVROLET  Equinox        2011       Jeep
# 2      45774419   8467     -          HONDA      FIT        2006  Hatchback
# 3      45769185   3607   862           FORD   Escape        2011       Jeep
# 4      45809263  11726   446          HONDA      FIT        2014  Hatchback
# ...         ...    ...   ...            ...      ...         ...        ...
# 19232  45798355   8467     -  MERCEDES-BENZ  CLK 200        1999      Coupe
# 19233  45778856  15681   831        HYUNDAI   Sonata        2011      Sedan
# 19234  45804997  26108   836        HYUNDAI   Tucson        2010       Jeep
# 19235  45793526   5331  1288      CHEVROLET  Captiva        2007       Jeep
# 19236  45813273    470   753        HYUNDAI   Sonata        2012      Sedan
#
#       Leather interior Fuel type Engine volume    Mileage  Cylinders  \
# 0                  Yes    Hybrid           3.5  186005 km          6
# 1                   No    Petrol             3  192000 km          6
# 2                   No    Petrol           1.3  200000 km          4
# 3                  Yes    Hybrid           2.5  168966 km          4
# 4                  Yes    Petrol           1.3   91901 km          4
# ...                ...       ...           ...        ...        ...
# 19232              Yes       CNG     2.0 Turbo  300000 km          4
# 19233              Yes    Petrol           2.4  161600 km          4
# 19234              Yes    Diesel             2  116365 km          4
# 19235              Yes    Diesel             2   51258 km          4
# 19236              Yes    Hybrid           2.4  186923 km          4
#
#       Gear box type Drive wheels  Doors             Wheel   Color  Airbags
# 0         Automatic          4x4  4-May        Left wheel  Silver       12
# 1         Tiptronic          4x4  4-May        Left wheel   Black        8
# 2          Variator        Front  4-May  Right-hand drive   Black        2
# 3         Automatic          4x4  4-May        Left wheel   White        0
# 4         Automatic        Front  4-May        Left wheel  Silver        4
# ...             ...          ...    ...               ...     ...      ...
# 19232        Manual         Rear  2-Mar        Left wheel  Silver        5
# 19233     Tiptronic        Front  4-May        Left wheel     Red        8
# 19234     Automatic        Front  4-May        Left wheel    Grey        4
# 19235     Automatic        Front  4-May        Left wheel   Black        4
# 19236     Automatic        Front  4-May        Left wheel   White       12
#
# [19237 rows x 18 columns]

# %%
data.describe()
# Out:
#                  ID         Price    Prod. year     Cylinders       Airbags
# count  1.923700e+04  1.923700e+04  19237.000000  19237.000000  19237.000000
# mean   4.557654e+07  1.855593e+04   2010.912824      4.582991      6.582627
# std    9.365914e+05  1.905813e+05      5.668673      1.199933      4.320168
# min    2.074688e+07  1.000000e+00   1939.000000      1.000000      0.000000
# 25%    4.569837e+07  5.331000e+03   2009.000000      4.000000      4.000000
# 50%    4.577231e+07  1.317200e+04   2012.000000      4.000000      6.000000
# 75%    4.580204e+07  2.207500e+04   2015.000000      4.000000     12.000000
# max    4.581665e+07  2.630750e+07   2020.000000     16.000000     16.000000

# %%
data.head()
# Out:
#          ID  Price  Levy Manufacturer    Model  Prod. year   Category  \
# 0  45654403  13328  1399        LEXUS   RX 450        2010       Jeep
# 1  44731507  16621  1018    CHEVROLET  Equinox        2011       Jeep
# 2  45774419   8467     -        HONDA      FIT        2006  Hatchback
# 3  45769185   3607   862         FORD   Escape        2011       Jeep
# 4  45809263  11726   446        HONDA      FIT        2014  Hatchback
#
#   Leather interior Fuel type Engine volume    Mileage  Cylinders  \
# 0              Yes    Hybrid           3.5  186005 km          6
# 1               No    Petrol             3  192000 km          6
# 2               No    Petrol           1.3  200000 km          4
# 3              Yes    Hybrid           2.5  168966 km          4
# 4              Yes    Petrol           1.3   91901 km          4
#
#   Gear box type Drive wheels  Doors             Wheel   Color  Airbags
# 0     Automatic          4x4  4-May        Left wheel  Silver       12
# 1     Tiptronic          4x4  4-May        Left wheel   Black        8
# 2      Variator        Front  4-May  Right-hand drive   Black        2
# 3     Automatic          4x4  4-May        Left wheel   White        0
# 4     Automatic        Front  4-May        Left wheel  Silver        4

# %%
dataf.head()
# Out:
#          ID  Price  Levy Manufacturer    Model  Prod. year   Category  \
# 0  45654403  13328  1399        LEXUS   RX 450        2010       Jeep
# 1  44731507  16621  1018    CHEVROLET  Equinox        2011       Jeep
# 2  45774419   8467     -        HONDA      FIT        2006  Hatchback
# 3  45769185   3607   862         FORD   Escape        2011       Jeep
# 4  45809263  11726   446        HONDA      FIT        2014  Hatchback
#
#   Leather interior Fuel type Engine volume    Mileage  Cylinders  \
# 0              Yes    Hybrid           3.5  186005 km          6
# 1               No    Petrol             3  192000 km          6
# 2               No    Petrol           1.3  200000 km          4
# 3              Yes    Hybrid           2.5  168966 km          4
# 4              Yes    Petrol           1.3   91901 km          4
#
#   Gear box type Drive wheels  Doors             Wheel   Color  Airbags
# 0     Automatic          4x4  4-May        Left wheel  Silver       12
# 1     Tiptronic          4x4  4-May        Left wheel   Black        8
# 2      Variator        Front  4-May  Right-hand drive   Black        2
# 3     Automatic          4x4  4-May        Left wheel   White        0
# 4     Automatic        Front  4-May        Left wheel  Silver        4

# %%
data.isnull()
# Out:
#           ID  Price   Levy  Manufacturer  Model  Prod. year  Category  \
# 0      False  False  False         False  False       False     False
# 1      False  False  False         False  False       False     False
# 2      False  False  False         False  False       False     False
# 3      False  False  False         False  False       False     False
# 4      False  False  False         False  False       False     False
# ...      ...    ...    ...           ...    ...         ...       ...
# 19232  False  False  False         False  False       False     False
# 19233  False  False  False         False  False       False     False
# 19234  False  False  False         False  False       False     False
# 19235  False  False  False         False  False       False     False
# 19236  False  False  False         False  False       False     False
#
#        Leather interior  Fuel type  Engine volume  Mileage  Cylinders  \
# 0                 False      False          False    False      False
# 1                 False      False          False    False      False
# 2                 False      False          False    False      False
# 3                 False      False          False    False      False
# 4                 False      False          False    False      False
# ...                 ...        ...            ...      ...        ...
# 19232             False      False          False    False      False
# 19233             False      False          False    False      False
# 19234             False      False          False    False      False
# 19235             False      False          False    False      False
# 19236             False      False          False    False      False
#
#        Gear box type  Drive wheels  Doors  Wheel  Color  Airbags
# 0              False         False  False  False  False    False
# 1              False         False  False  False  False    False
# 2              False         False  False  False  False    False
# 3              False         False  False  False  False    False
# 4              False         False  False  False  False    False
# ...              ...           ...    ...    ...    ...      ...
# 19232          False         False  False  False  False    False
# 19233          False         False  False  False  False    False
# 19234          False         False  False  False  False    False
# 19235          False         False  False  False  False    False
# 19236          False         False  False  False  False    False
#
# [19237 rows x 18 columns]

# %%
data.isnull().sum()
# Out:
# ID                  0
# Price               0
# Levy                0
# Manufacturer        0
# Model               0
# Prod. year          0
# Category            0
# Leather interior    0
# Fuel type           0
# Engine volume       0
# Mileage             0
# Cylinders           0
# Gear box type       0
# Drive wheels        0
# Doors               0
# Wheel               0
# Color               0
# Airbags             0
# dtype: int64

# %%
dataf.describe()
# Out:
#                  ID         Price    Prod. year     Cylinders       Airbags
# count  1.923700e+04  1.923700e+04  19237.000000  19237.000000  19237.000000
# mean   4.557654e+07  1.855593e+04   2010.912824      4.582991      6.582627
# std    9.365914e+05  1.905813e+05      5.668673      1.199933      4.320168
# min    2.074688e+07  1.000000e+00   1939.000000      1.000000      0.000000
# 25%    4.569837e+07  5.331000e+03   2009.000000      4.000000      4.000000
# 50%    4.577231e+07  1.317200e+04   2012.000000      4.000000      6.000000
# 75%    4.580204e+07  2.207500e+04   2015.000000      4.000000     12.000000
# max    4.581665e+07  2.630750e+07   2020.000000     16.000000     16.000000

# %%
data.dtypes
# Out:
# ID                   int64
# Price                int64
# Levy                object
# Manufacturer        object
# Model               object
# Prod. year           int64
# Category            object
# Leather interior    object
# Fuel type           object
# Engine volume       object
# Mileage             object
# Cylinders            int64
# Gear box type       object
# Drive wheels        object
# Doors               object
# Wheel               object
# Color               object
# Airbags              int64
# dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19237 entries, 0 to 19236
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                19237 non-null  int64
#  1   Price             19237 non-null  int64
#  2   Levy              19237 non-null  object
#  3   Manufacturer      19237 non-null  object
#  4   Model             19237 non-null  object
#  5   Prod. year        19237 non-null  int64
#  6   Category          19237 non-null  object
#  7   Leather interior  19237 non-null  object
#  8   Fuel type         19237 non-null  object
#  9   Engine volume     19237 non-null  object
#  10  Mileage           19237 non-null  object
#  11  Cylinders         19237 non-null  int64
#  12  Gear box type     19237 non-null  object
#  13  Drive wheels      19237 non-null  object
#  14  Doors             19237 non-null  object
#  15  Wheel             19237 non-null  object
#  16  Color             19237 non-null  object
#  17  Airbags           19237 non-null  int64
# dtypes: int64(5), object(13)
# memory usage: 2.6+ MB

# %%
data.head()
# print(p)
# Out:
#          ID  Price  Levy Manufacturer    Model  Prod. year   Category  \
# 0  45654403  13328  1399        LEXUS   RX 450        2010       Jeep
# 1  44731507  16621  1018    CHEVROLET  Equinox        2011       Jeep
# 2  45774419   8467     -        HONDA      FIT        2006  Hatchback
# 3  45769185   3607   862         FORD   Escape        2011       Jeep
# 4  45809263  11726   446        HONDA      FIT        2014  Hatchback
#
#   Leather interior Fuel type Engine volume    Mileage  Cylinders  \
# 0              Yes    Hybrid           3.5  186005 km          6
# 1               No    Petrol             3  192000 km          6
# 2               No    Petrol           1.3  200000 km          4
# 3              Yes    Hybrid           2.5  168966 km          4
# 4              Yes    Petrol           1.3   91901 km          4
#
#   Gear box type Drive wheels  Doors             Wheel   Color  Airbags
# 0     Automatic          4x4  4-May        Left wheel  Silver       12
# 1     Tiptronic          4x4  4-May        Left wheel   Black        8
# 2      Variator        Front  4-May  Right-hand drive   Black        2
# 3     Automatic          4x4  4-May        Left wheel   White        0
# 4     Automatic        Front  4-May        Left wheel  Silver        4

# %%
# identify duplicate rows
duplicate_rows = data[data.duplicated()]
print(duplicate_rows)
# Out:
#              ID  Price  Levy   Manufacturer        Model  Prod. year  \
# 425    45815372   7840     -  MERCEDES-BENZ        E 200        1998
# 1581   45815363   8781     -         TOYOTA          Ist        2002
# 1697   45732125  18503     -         TOYOTA        Prius        2010
# 1972   45507765  20385     -  MERCEDES-BENZ      CLS 500        2005
# 2131   45815363   8781     -         TOYOTA          Ist        2002
# ...         ...    ...   ...            ...          ...         ...
# 18974  45815465   2352  1273          LEXUS       IS 350        2015
# 19137  45810466  15125   642      CHEVROLET      Orlando        2012
# 19200  45725908  36065   640  MERCEDES-BENZ  CLA 250 AMG        2013
# 19203  45761487  13485   645         TOYOTA        Prius        2011
# 19210  45732939   8311   642        HYUNDAI       Sonata        2012
#
#         Category Leather interior Fuel type Engine volume    Mileage  \
# 425        Sedan               No       CNG             2  180003 km
# 1581   Hatchback               No    Petrol           1.5  117000 km
# 1697       Sedan               No    Petrol           1.8  162000 km
# 1972       Sedan              Yes    Petrol             5  230000 km
# 2131   Hatchback               No    Petrol           1.5  117000 km
# ...          ...              ...       ...           ...        ...
# 18974      Sedan              Yes    Petrol           3.5   80856 km
# 19137       Jeep              Yes    Diesel             2  156834 km
# 19200      Sedan              Yes    Petrol     2.0 Turbo   68000 km
# 19203      Sedan               No    Hybrid           1.8  281600 km
# 19210      Sedan              Yes       LPG             2   36545 km
#
#        Cylinders Gear box type Drive wheels  Doors             Wheel   Color  \
# 425            4        Manual         Rear  4-May        Left wheel   Black
# 1581           4     Automatic          4x4  4-May  Right-hand drive     Red
# 1697           4     Automatic        Front  4-May        Left wheel    Grey
# 1972           8     Tiptronic         Rear  4-May        Left wheel  Silver
# 2131           4     Automatic          4x4  4-May  Right-hand drive     Red
# ...          ...           ...          ...    ...               ...     ...
# 18974          6     Automatic          4x4  4-May        Left wheel   Black
# 19137          4     Automatic        Front  4-May        Left wheel  Golden
# 19200          4     Tiptronic        Front  4-May        Left wheel     Red
# 19203          6     Automatic        Front  4-May        Left wheel    Grey
# 19210          4     Automatic        Front  4-May        Left wheel   White
#
#        Airbags
# 425          4
# 1581         4
# 1697        12
# 1972        10
# 2131         4
# ...        ...
# 18974       12
# 19137        4
# 19200       12
# 19203        8
# 19210        4
#
# [313 rows x 18 columns]

# %%
# count the number of duplicates
num_duplicates = data.duplicated().sum()
print(num_duplicates)
# Out:
# 313

# %%
# check for duplicate value in specific colimn
duplicate_values = data.duplicated(subset=['Price', 'Model'])
print(duplicate_values)
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 19232     True
# 19233     True
# 19234    False
# 19235     True
# 19236     True
# Length: 19237, dtype: bool

# %%
data['Manufacturer'].value_counts()
# Out:
# HYUNDAI          3769
# TOYOTA           3662
# MERCEDES-BENZ    2076
# FORD             1111
# CHEVROLET        1069
#                  ...
# TESLA               1
# PONTIAC             1
# SATURN              1
# ASTON MARTIN        1
# GREATWALL           1
# Name: Manufacturer, Length: 65, dtype: int64

# %%
data['Model'].value_counts()
# Out:
# Prius                    1083
# Sonata                   1079
# Camry                     938
# Elantra                   922
# E 350                     542
#                          ...
# Feroza                      1
# C-MAX C-MAX                 1
# X1 4X4                      1
# Land Cruiser Prado RX       1
# Prius C aqua                1
# Name: Model, Length: 1590, dtype: int64

# %%
data['ID'].value_counts()
# Out:
# 45815365    8
# 45815361    8
# 45815363    7
# 45815368    7
# 45723475    7
#            ..
# 45774312    1
# 45732621    1
# 45773011    1
# 45774019    1
# 45813273    1
# Name: ID, Length: 18924, dtype: int64

# %%
average_price = data['Price'].mean()
print("Average Price:", average_price)
# Out:
# Average Price: 18555.92722357956

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(11, 6))
data['Manufacturer'].value_counts().plot(kind='bar')
plt.xlabel('Manufacturer')
plt.ylabel('Price')
plt.title('Counts of Model')
plt.show()
# Out:
# C:\Users\KIIT\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 144 (\x90) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# import matplotlib.pyplot as plt

# plt.figure(figsize=(11,6))
# data['Manufacturer'].value_counts().plot(kind='pie')
# plt.xlabel('Manufacturer')
# plt.ylabel('Price')
# plt.title('Counts of Model')
# plt.show()

# %%
plt.figure(figsize=(9, 15))
top_Manufacturer = data['Manufacturer'].value_counts().nlargest(5)
top_Manufacturer.plot(kind='pie', autopct='%1.1f%%')
plt.title('Top 5 Body Type Distribution')
plt.show()

# %%
plt.figure(figsize=(12, 6))
hg=data['Price'].value_counts().nlargest(50)
# data['Price'].plot(kind='hist', bins=10)
hg.plot(kind='hist',edgecolor="black",bins=10)
plt.xlabel('Price')
plt.ylabel('Manufacturer')
plt.title('Manufacturer Distribution')
plt.show()

# %%
# plt.figure(figsize=(12, 6))
# hg=data['Manufacturer'].value_counts().nlargest(50)
# # data['Price'].plot(kind='hist', bins=10)
# hg.plot(kind='hist',edgecolor="black",bins=10)
# plt.xlabel('Manufacturer')
# plt.ylabel('Price')
# plt.title('Manufacturer Distribution')
# plt.show()

# %%
import seaborn as sb

sb.set(rc={'figure.figsize': (8, 6)})
# plt.figure(figsize=(12, 6))
plt.figure(figsize=(8, 6))
sb.scatterplot(x='Price', y='Color', data=data)
plt.title('Price vs. Color')
plt.show()

# %%
data.head()
# Out:
#          ID  Price  Levy Manufacturer    Model  Prod. year   Category  \
# 0  45654403  13328  1399        LEXUS   RX 450        2010       Jeep
# 1  44731507  16621  1018    CHEVROLET  Equinox        2011       Jeep
# 2  45774419   8467     -        HONDA      FIT        2006  Hatchback
# 3  45769185   3607   862         FORD   Escape        2011       Jeep
# 4  45809263  11726   446        HONDA      FIT        2014  Hatchback
#
#   Leather interior Fuel type Engine volume    Mileage  Cylinders  \
# 0              Yes    Hybrid           3.5  186005 km          6
# 1               No    Petrol             3  192000 km          6
# 2               No    Petrol           1.3  200000 km          4
# 3              Yes    Hybrid           2.5  168966 km          4
# 4              Yes    Petrol           1.3   91901 km          4
#
#   Gear box type Drive wheels  Doors             Wheel   Color  Airbags
# 0     Automatic          4x4  4-May        Left wheel  Silver       12
# 1     Tiptronic          4x4  4-May        Left wheel   Black        8
# 2      Variator        Front  4-May  Right-hand drive   Black        2
# 3     Automatic          4x4  4-May        Left wheel   White        0
# 4     Automatic        Front  4-May        Left wheel  Silver        4

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19237 entries, 0 to 19236
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                19237 non-null  int64
#  1   Price             19237 non-null  int64
#  2   Levy              19237 non-null  object
#  3   Manufacturer      19237 non-null  object
#  4   Model             19237 non-null  object
#  5   Prod. year        19237 non-null  int64
#  6   Category          19237 non-null  object
#  7   Leather interior  19237 non-null  object
#  8   Fuel type         19237 non-null  object
#  9   Engine volume     19237 non-null  object
#  10  Mileage           19237 non-null  object
#  11  Cylinders         19237 non-null  int64
#  12  Gear box type     19237 non-null  object
#  13  Drive wheels      19237 non-null  object
#  14  Doors             19237 non-null  object
#  15  Wheel             19237 non-null  object
#  16  Color             19237 non-null  object
#  17  Airbags           19237 non-null  int64
# dtypes: int64(5), object(13)
# memory usage: 2.6+ MB

# %%
# Assuming the given data is stored in a Pandas DataFrame called "data"

# Select the numerical columns for outlier detection
numeric_cols = ['ID', 'Price', 'Prod. year', 'Engine volume', 'Mileage', 'Doors', 'Airbags']
numeric_data = data[numeric_cols]

# Calculate z-scores for each column
z_scores = (numeric_data - numeric_data.mean()) / numeric_data.std()

# Define a threshold for identifying outliers (e.g., z-score > 3 or z-score < -3)
threshold = 3

# Find outliers in each column
outliers = (z_scores > threshold) | (z_scores < -threshold)

# Count the number of outliers in each column
num_outliers = outliers.sum()

# Display the rows with outliers
outlier_rows = data[outliers.any(axis=1)]

# Print the number of outliers in each column
print("Number of outliers in each column:")
print(num_outliers)

# Print the rows with outliers
print("Rows with outliers:")
print(outlier_rows)
# Out:
# Number of outliers in each column:
# Airbags            0
# Doors              0
# Engine volume      0
# ID               264
# Mileage            0
# Price              3
# Prod. year       150
# dtype: int64
# Rows with outliers:
#              ID  Price  Levy   Manufacturer           Model  Prod. year  \
# 96     45776745  18817     -         NISSAN          Patrol        1990
# 144    45759786   4300     -  MERCEDES-BENZ             208        1985
# 194    45776729  19757     -         NISSAN      Patrol Y60        1990
# 219    41704944  19130  2148  MERCEDES-BENZ         CLS 550        2010
# 228    45788888   6000     -           JEEP  Grand Cherokee        1993
# ...         ...    ...   ...            ...             ...         ...
# 19041  45792773   3200     -            GAZ              20        1953
# 19061  25368573  12544     -            BMW             325        2002
# 19130  45812919   3136     -  MERCEDES-BENZ       E 230 124        1990
# 19151  42287915  21953     -           FORD         Transit        1999
# 19229  39977395     50     -         TOYOTA           Prius        2008
#
#         Category Leather interior Fuel type Engine volume     Mileage  \
# 96          Jeep               No    Diesel     2.8 Turbo   333333 km
# 144    Universal               No    Diesel           2.5  1111111 km
# 194         Jeep               No    Diesel     2.8 Turbo   222222 km
# 219        Sedan              Yes    Petrol           5.5   157000 km
# 228         Jeep               No    Petrol             4   240000 km
# ...          ...              ...       ...           ...         ...
# 19041       Jeep               No    Petrol           3.2   100000 km
# 19061      Sedan              Yes       CNG           2.5   220000 km
# 19130      Sedan               No       CNG           2.3   350000 km
# 19151   Microbus               No    Diesel     2.5 Turbo   430000 km
# 19229  Hatchback               No    Hybrid           1.5   150000 km
#
#        Cylinders Gear box type Drive wheels  Doors       Wheel   Color  \
# 96             4        Manual         Rear  4-May  Left wheel   Black
# 144            4        Manual         Rear  4-May  Left wheel   Black
# 194            4        Manual         Rear  4-May  Left wheel   Black
# 219            4     Automatic        Front  4-May  Left wheel    Grey
# 228            6     Automatic          4x4  4-May  Left wheel   Green
# ...          ...           ...          ...    ...         ...     ...
# 19041          4        Manual          4x4  2-Mar  Left wheel   Green
# 19061          6     Tiptronic         Rear  4-May  Left wheel  Silver
# 19130          4     Automatic         Rear  4-May  Left wheel    Grey
# 19151          4        Manual         Rear  4-May  Left wheel   White
# 19229          4     Automatic        Front  4-May  Left wheel  Silver
#
#        Airbags
# 96           0
# 144          1
# 194          0
# 219         10
# 228          5
# ...        ...
# 19041        0
# 19061        8
# 19130        0
# 19151        1
# 19229        6
#
# [412 rows x 18 columns]
# C:\Users\KIIT\AppData\Local\Temp\ipykernel_4808\3691414583.py:8: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   z_scores = (numeric_data - numeric_data.mean()) / numeric_data.std()

# %%
from scipy.stats import mstats

# Assuming the given data is stored in a Pandas DataFrame called "data"

# Select the numerical columns for outlier transformation
numeric_cols = ['ID', 'Price', 'Prod. year', 'Engine volume', 'Mileage', 'Doors', 'Airbags']
numeric_data = data[numeric_cols]

# Define the percentiles for winsorization (e.g., 5% from each tail)
lower_percentile = 0.05
upper_percentile = 0.95

# Apply winsorization to transform outliers
transformed_data = pd.DataFrame()
for col in numeric_cols:
    transformed_data[col] = mstats.winsorize(numeric_data[col], limits=[lower_percentile, upper_percentile])

# Replace the original numeric columns with the transformed values
data[numeric_cols] = transformed_data

# Display the transformed data
print(data)
# Out:
# C:\Users\KIIT\anaconda3\lib\site-packages\scipy\stats\_stats_py.py:110: RuntimeWarning: The input array could not be properly checked for nan values. nan values will be ignored.
#   warnings.warn("The input array could not be properly "
# C:\Users\KIIT\anaconda3\lib\site-packages\scipy\stats\_stats_py.py:110: RuntimeWarning: The input array could not be properly checked for nan values. nan values will be ignored.
#   warnings.warn("The input array could not be properly "
#              ID  Price  Levy   Manufacturer    Model  Prod. year   Category  \
# 0      44765681    314  1399          LEXUS   RX 450        1999       Jeep
# 1      44765681    314  1018      CHEVROLET  Equinox        1999       Jeep
# 2      44765681    314     -          HONDA      FIT        1999  Hatchback
# 3      44765681    314   862           FORD   Escape        1999       Jeep
# 4      44765681    314   446          HONDA      FIT        1999  Hatchback
# ...         ...    ...   ...            ...      ...         ...        ...
# 19232  44765681    314     -  MERCEDES-BENZ  CLK 200        1999      Coupe
# 19233  44765681    314   831        HYUNDAI   Sonata        1999      Sedan
# 19234  44765681    314   836        HYUNDAI   Tucson        1999       Jeep
# 19235  44765681    314  1288      CHEVROLET  Captiva        1999       Jeep
# 19236  44765681    314   753        HYUNDAI   Sonata        1999      Sedan
#
#       Leather interior Fuel type Engine volume    Mileage  Cylinders  \
# 0                  Yes    Hybrid           1.4  100000 km          6
# 1                   No    Petrol           1.4  100000 km          6
# 2                   No    Petrol           1.4  100000 km          4
# 3                  Yes    Hybrid           1.4  100000 km          4
# 4                  Yes    Petrol           1.4  100000 km          4
# ...                ...       ...           ...        ...        ...
# 19232              Yes       CNG           1.4  100000 km          4
# 19233              Yes    Petrol           1.4  100000 km          4
# 19234              Yes    Diesel           1.4  100000 km          4
# 19235              Yes    Diesel           1.4  100000 km          4
# 19236              Yes    Hybrid           1.4  100000 km          4
#
#       Gear box type Drive wheels  Doors             Wheel   Color  Airbags
# 0         Automatic          4x4  4-May        Left wheel  Silver        0
# 1         Tiptronic          4x4  4-May        Left wheel   Black        0
# 2          Variator        Front  4-May  Right-hand drive   Black        0
# 3         Automatic          4x4  4-May        Left wheel   White        0
# 4         Automatic        Front  4-May        Left wheel  Silver        0
# ...             ...          ...    ...               ...     ...      ...
# 19232        Manual         Rear  4-May        Left wheel  Silver        0
# 19233     Tiptronic        Front  4-May        Left wheel     Red        0
# 19234     Automatic        Front  4-May        Left wheel    Grey        0
# 19235     Automatic        Front  4-May        Left wheel   Black        0
# 19236     Automatic        Front  4-May        Left wheel   White        0
#
# [19237 rows x 18 columns]
# C:\Users\KIIT\anaconda3\lib\site-packages\scipy\stats\_stats_py.py:110: RuntimeWarning: The input array could not be properly checked for nan values. nan values will be ignored.
#   warnings.warn("The input array could not be properly "

# %%
# Format issue
data['Price'] = data['Price'].astype('float')
print(data['Price'])
# Out:
# 0        314.0
# 1        314.0
# 2        314.0
# 3        314.0
# 4        314.0
#          ...
# 19232    314.0
# 19233    314.0
# 19234    314.0
# 19235    314.0
# 19236    314.0
# Name: Price, Length: 19237, dtype: float64
